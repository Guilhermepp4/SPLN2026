# %%
# !pip install spacy datasets
# Out:
# Requirement already satisfied: spacy in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (3.8.11)
# Requirement already satisfied: datasets in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (4.8.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /home/guilherme/.local/lib/python3.10/site-packages (from spacy) (2.2.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/guilherme/.local/lib/python3.10/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in /home/guilherme/.local/lib/python3.10/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/guilherme/.local/lib/python3.10/site-packages (from spacy) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/guilherme/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: typer>=0.24.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.1)
# Requirement already satisfied: wrapt in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (2.1.2)
# Requirement already satisfied: filelock in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from datasets) (3.29.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /home/guilherme/.local/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in /home/guilherme/.local/lib/python3.10/site-packages (from datasets) (0.27.2)
# Requirement already satisfied: xxhash in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from datasets) (1.11.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in /home/guilherme/.local/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/guilherme/.local/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.6)
# Requirement already satisfied: sniffio in /home/guilherme/.local/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/guilherme/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: click>=8.2.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/guilherme/.local/lib/python3.10/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/guilherme/.local/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/guilherme/.local/lib/python3.10/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/guilherme/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from pandas->datasets) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/guilherme/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/guilherme/anaconda3/envs/EG/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
# !python -m spacy convert arquivo_ner_train.iob ./datasets -c iob
# Out:
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (3716 documents):
# datasets/arquivo_ner_train.spacy

# %%
# !python -m spacy convert arquivo_ner_test.iob ./datasets -c iob
# Out:
# ℹ Auto-detected token-per-line NER format
# ℹ Grouping every 1 sentences into a document.
# ⚠ To generate better training data, you may want to group sentences
# into documents with `-n 10`.
# ✔ Generated output file (930 documents):
# datasets/arquivo_ner_test.spacy

# %%
# Criar a configuração inicial para NER em Português
# !python -m spacy init config config.cfg --lang pt --pipeline ner --optimize accuracy
# Out:
# ✘ The provided output file already exists. To force overwriting the
# config file, set the --force or -F flag.

# %%
# !python -m spacy download pt_core_news_lg
# Out:
# Collecting pt-core-news-lg==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.8.0/pt_core_news_lg-3.8.0-py3-none-any.whl (568.2 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')

# %%
# !python -m spacy train config.cfg --output ./output --paths.train ./datasets/arquivo_ner_train.spacy --paths.dev ./datasets/arquivo_ner_test.spacy
# Out:
# ℹ Saving to output directory: output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     55.45    0.90    1.60    0.63    0.01
#   0     200        318.69   2543.91   86.25   90.71   82.21    0.86
#   0     400        283.74   1010.54   91.03   93.44   88.74    0.91
#   0     600         61.90   1046.22   92.91   94.40   91.46    0.93
#   1     800        124.19   1159.21   94.00   94.22   93.77    0.94
#   1    1000       1260.29   1002.93   94.67   97.43   92.06    0.95
#   2    1200        169.53   1207.67   95.48   95.67   95.30    0.95
#   2    1400        141.96   1111.66   96.19   97.51   94.91    0.96
#   3    1600        160.75   1073.78   97.43   97.17   97.69    0.97
#   4    1800        148.02   1040.28   97.84   98.16   97.51    0.98
#   6    2000        122.01    958.21   98.62   98.54   98.71    0.99
#   7    2200        176.74    991.52   98.77   98.74   98.80    0.99
#   9    2400        273.37   1005.01   98.86   99.10   98.62    0.99
#  12    2600        221.85    827.22   99.21   99.28   99.13    0.99
#  14    2800        275.26    807.99   98.89   98.80   98.98    0.99
#  16    3000        209.78    642.22   99.01   99.16   98.86    0.99
#  18    3200        212.77    583.30   99.18   99.28   99.07    0.99
#  20    3400        314.61    655.31   99.12   99.13   99.10    0.99
#  22    3600        252.83    522.27   99.07   99.13   99.01    0.99
#  24    3800        393.27    583.09   99.31   99.22   99.40    0.99
#  26    4000        262.78    465.32   99.05   99.49   98.62    0.99
#  28    4200        338.96    447.23   99.31   99.55   99.07    0.99
#  30    4400        264.49    441.90   99.12   99.04   99.19    0.99
#  32    4600        265.02    394.14   99.08   99.31   98.86    0.99
#  34    4800        324.21    389.99   99.33   99.37   99.28    0.99
#  36    5000        290.91    378.33   99.31   99.31   99.31    0.99
#  38    5200        351.04    421.46   99.19   99.16   99.22    0.99
#  41    5400        328.58    344.33   99.03   99.10   98.95    0.99
#  43    5600        764.77    397.28   99.31   99.40   99.22    0.99
#  45    5800        407.42    353.42   99.22   99.43   99.01    0.99
#  47    6000        420.23    335.82   99.15   99.16   99.13    0.99
#  49    6200        546.21    376.39   99.19   99.40   98.98    0.99
#  51    6400        657.24    277.31   99.22   99.25   99.19    0.99
# ✔ Saved pipeline to output directory
# output/model-last

# %%
# !python -m spacy evaluate output/model-best datasets/arquivo_ner_test.spacy
# Out:
# ℹ Using CPU
#
# ================================== Results ==================================
#
# TOK     -
# NER P   99.37
# NER R   99.28
# NER F   99.33
# SPEED   4461
#
#
# =============================== NER (per type) ===============================
#
#                   P       R       F
# Data          99.79   99.79   99.79
# Pessoa        99.46   99.60   99.53
# Local         99.73   99.56   99.65
# Organizacao   95.96   95.96   95.96
# Profissao     96.60   94.67   95.62
